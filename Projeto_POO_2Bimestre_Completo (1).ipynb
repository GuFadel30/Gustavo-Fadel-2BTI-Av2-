# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
# Definição da classe principal
class Receita:
    def __init__(self, titulo, ingredientes, tempo_preparo):
        self.titulo = titulo
        self.ingredientes = ingredientes  # lista de ingredientes
        self.tempo_preparo = tempo_preparo  # tempo em minutos

    # Método de exibição dos dados da receita
    def exibir_dados(self):
        print(f"Receita: {self.titulo}")
        print(f"Ingredientes: {', '.join(self.ingredientes)}")
        print(f"Tempo de preparo: {self.tempo_preparo} minutos")
        print("-" * 40)


# Criação de dois objetos da classe Receita
receita1 = Receita(
    "Bolo de Chocolate",
    ["farinha", "açúcar", "chocolate em pó", "ovos", "leite", "fermento"],
    45
)

receita2 = Receita(
    "Salada de Frutas",
    ["maçã", "banana", "laranja", "mamão", "mel", "limão"],
    10
)

# Exibindo os dados das receitas criadas
receita1.exibir_dados()
receita2.exibir_dados()
# Out:
# Receita: Bolo de Chocolate
# Ingredientes: farinha, açúcar, chocolate em pó, ovos, leite, fermento
# Tempo de preparo: 45 minutos
# ----------------------------------------
# Receita: Salada de Frutas
# Ingredientes: maçã, banana, laranja, mamão, mel, limão
# Tempo de preparo: 10 minutos
# ----------------------------------------

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
# Classe principal
class Receita:
    def __init__(self, titulo, ingredientes, tempo_preparo):
        self.titulo = titulo
        self.ingredientes = ingredientes
        self.tempo_preparo = tempo_preparo

    def exibir_dados(self):
        print(f"Receita: {self.titulo}")
        print(f"Ingredientes: {', '.join(self.ingredientes)}")
        print(f"Tempo de preparo: {self.tempo_preparo} minutos")
        print("-" * 40)

    # Método de ação 1
    def adicionar_ingrediente(self, ingrediente):
        self.ingredientes.append(ingrediente)
        print(f"Ingrediente '{ingrediente}' adicionado com sucesso!")

    # Método de ação 2
    def alterar_tempo_preparo(self, novo_tempo):
        self.tempo_preparo = novo_tempo
        print(f"Tempo de preparo alterado para {novo_tempo} minutos.")


# Subclasse herdada de Receita
class ReceitaSobremesa(Receita):
    def __init__(self, titulo, ingredientes, tempo_preparo, nivel_acucar):
        super().__init__(titulo, ingredientes, tempo_preparo)
        self.nivel_acucar = nivel_acucar  # novo atributo específico da sobremesa

    # Método exclusivo da subclasse
    def verificar_acucar(self):
        if self.nivel_acucar > 50:
            print("Atenção: Sobremesa com alto teor de açúcar!")
        else:
            print("Nível de açúcar moderado.")


# Criando um objeto da subclasse
sobremesa1 = ReceitaSobremesa(
    "Pudim de Leite",
    ["leite condensado", "leite", "ovos", "açúcar"],
    90,
    nivel_acucar=60
)

# Testando métodos
sobremesa1.exibir_dados()
sobremesa1.verificar_acucar()
sobremesa1.adicionar_ingrediente("baunilha")
sobremesa1.alterar_tempo_preparo(95)
# Out:
# Receita: Pudim de Leite
# Ingredientes: leite condensado, leite, ovos, açúcar
# Tempo de preparo: 90 minutos
# ----------------------------------------
# Atenção: Sobremesa com alto teor de açúcar!
# Ingrediente 'baunilha' adicionado com sucesso!
# Tempo de preparo alterado para 95 minutos.

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
# Classe principal com encapsulamento
class Receita:
    def __init__(self, titulo, ingredientes, tempo_preparo):
        self.titulo = titulo
        self.ingredientes = ingredientes
        self.__tempo_preparo = tempo_preparo  # atributo privado

    # Método para exibir dados
    def exibir_dados(self):
        print(f"Receita: {self.titulo}")
        print(f"Ingredientes: {', '.join(self.ingredientes)}")
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")
        print("-" * 40)

    # Getter para tempo de preparo
    def get_tempo_preparo(self):
        return self.__tempo_preparo

    # Setter para tempo de preparo
    def set_tempo_preparo(self, novo_tempo):
        if novo_tempo > 0:
            self.__tempo_preparo = novo_tempo
            print(f"Tempo de preparo atualizado para {novo_tempo} minutos.")
        else:
            print("Erro: o tempo de preparo deve ser positivo.")

    # Método com lógica interna (abstração)
    def verificar_preparo_rapido(self):
        if self.__tempo_preparo <= 30:
            return "Receita rápida!"
        else:
            return "Receita mais demorada."


# Teste com objeto
receita3 = Receita(
    "Omelete Simples",
    ["ovos", "sal", "queijo", "cebola"],
    15
)

# Usando os métodos definidos
receita3.exibir_dados()
print(receita3.verificar_preparo_rapido())

receita3.set_tempo_preparo(25)
print(f"Tempo atualizado: {receita3.get_tempo_preparo()} minutos")
# Out:
# Receita: Omelete Simples
# Ingredientes: ovos, sal, queijo, cebola
# Tempo de preparo: 15 minutos
# ----------------------------------------
# Receita rápida!
# Tempo de preparo atualizado para 25 minutos.
# Tempo atualizado: 25 minutos

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3

# Classe principal
class Receita:
    def __init__(self, titulo, ingredientes, tempo_preparo):
        self.titulo = titulo
        self.ingredientes = ingredientes
        self.__tempo_preparo = tempo_preparo

    def get_tempo_preparo(self):
        return self.__tempo_preparo

    def set_tempo_preparo(self, tempo):
        if tempo > 0:
            self.__tempo_preparo = tempo

    # Método que será sobrescrito
    def exibir_dados(self):
        print(f"Receita: {self.titulo}")
        print(f"Ingredientes: {', '.join(self.ingredientes)}")
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")
        print("-" * 40)


# Subclasse com polimorfismo
class ReceitaSobremesa(Receita):
    def __init__(self, titulo, ingredientes, tempo_preparo, nivel_acucar):
        super().__init__(titulo, ingredientes, tempo_preparo)
        self.nivel_acucar = nivel_acucar

    # Polimorfismo: sobrescrevendo exibir_dados
    def exibir_dados(self):
        super().exibir_dados()
        print(f"Nível de açúcar: {self.nivel_acucar}%")
        print("-" * 40)


# Banco de dados: conexão e criação da tabela
def criar_banco():
    conexao = sqlite3.connect("receitas.db")
    cursor = conexao.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS receitas (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            titulo TEXT,
            ingredientes TEXT,
            tempo_preparo INTEGER
        )
    ''')
    conexao.commit()
    conexao.close()


# Inserir receita no banco
def inserir_receita(titulo, ingredientes, tempo_preparo):
    conexao = sqlite3.connect("receitas.db")
    cursor = conexao.cursor()
    cursor.execute('''
        INSERT INTO receitas (titulo, ingredientes, tempo_preparo)
        VALUES (?, ?, ?)
    ''', (titulo, ', '.join(ingredientes), tempo_preparo))
    conexao.commit()
    conexao.close()
    print("Receita inserida com sucesso no banco de dados!")


# Consultar todas as receitas
def consultar_receitas():
    conexao = sqlite3.connect("receitas.db")
    cursor = conexao.cursor()
    cursor.execute("SELECT * FROM receitas")
    resultados = cursor.fetchall()
    conexao.close()
    print("\n📋 RECEITAS NO BANCO DE DADOS:")
    for linha in resultados:
        print(f"ID: {linha[0]}, Título: {linha[1]}, Ingredientes: {linha[2]}, Tempo: {linha[3]} minutos")


# Excluir uma receita por ID
def deletar_receita(id_receita):
    conexao = sqlite3.connect("receitas.db")
    cursor = conexao.cursor()
    cursor.execute("DELETE FROM receitas WHERE id = ?", (id_receita,))
    conexao.commit()
    conexao.close()
    print(f"Receita com ID {id_receita} excluída com sucesso.")


# Execução de teste
if __name__ == "__main__":
    criar_banco()

    # Criando e exibindo uma receita comum
    receita_comum = Receita("Macarrão Alho e Óleo", ["macarrão", "alho", "óleo", "sal"], 20)
    receita_comum.exibir_dados()
    inserir_receita(receita_comum.titulo, receita_comum.ingredientes, receita_comum.get_tempo_preparo())

    # Criando e exibindo uma sobremesa com polimorfismo
    sobremesa = ReceitaSobremesa("Mousse de Limão", ["leite condensado", "creme de leite", "suco de limão"], 15, 45)
    sobremesa.exibir_dados()
    inserir_receita(sobremesa.titulo, sobremesa.ingredientes, sobremesa.get_tempo_preparo())

    # Consultar receitas no banco
    consultar_receitas()

    # Exemplo de exclusão (remova o comentário se quiser testar)
    # deletar_receita(1)  # Altere o ID conforme necessário
# Out:
# Receita: Macarrão Alho e Óleo
# Ingredientes: macarrão, alho, óleo, sal
# Tempo de preparo: 20 minutos
# ----------------------------------------
# Receita inserida com sucesso no banco de dados!
# Receita: Mousse de Limão
# Ingredientes: leite condensado, creme de leite, suco de limão
# Tempo de preparo: 15 minutos
# ----------------------------------------
# Nível de açúcar: 45%
# ----------------------------------------
# Receita inserida com sucesso no banco de dados!
#
# 📋 RECEITAS NO BANCO DE DADOS:
# ID: 1, Título: Arroz com Legumes, Ingredientes: arroz, cenoura, ervilha, alho, Tempo: 25 minutos
# ID: 2, Título: Brigadeiro, Ingredientes: leite condensado, chocolate, manteiga, Tempo: 10 minutos
# ID: 3, Título: papel, Ingredientes: papel,  el,  pel, Tempo: 30 minutos
# ID: 4, Título: Macarrão Alho e Óleo, Ingredientes: macarrão, alho, óleo, sal, Tempo: 20 minutos
# ID: 5, Título: Mousse de Limão, Ingredientes: leite condensado, creme de leite, suco de limão, Tempo: 15 minutos
# ...

# %%
import sys
# !{sys.executable} -m pip install mysql-connector-python

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# !pip install mysql-connector-python

import mysql.connector

# ================================
# CONFIGURAÇÃO DO BANCO DE DADOS
# ================================
def conectar_banco():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="",  # ou a senha do seu MySQL
        database="site_receitas"
    )

# ================================
# CLASSE PRINCIPAL: Receita
# ================================
class Receita:
    def __init__(self, titulo, ingredientes, tempo_preparo):
        self.titulo = titulo
        self.ingredientes = ingredientes
        self.__tempo_preparo = tempo_preparo

    def get_tempo_preparo(self):
        return self.__tempo_preparo

    def set_tempo_preparo(self, tempo):
        if tempo > 0:
            self.__tempo_preparo = tempo
        else:
            print("Tempo inválido!")

    def verificar_preparo_rapido(self):
        return self.__tempo_preparo <= 30

    def exibir_dados(self):
        print(f"\nReceita: {self.titulo}")
        print(f"Ingredientes: {', '.join(self.ingredientes)}")
        print(f"Tempo de preparo: {self.__tempo_preparo} minutos")
        print("Rápida?", "Sim" if self.verificar_preparo_rapido() else "Não")
        print("-" * 40)

# ================================
# SUBCLASSE: ReceitaSobremesa
# ================================
class ReceitaSobremesa(Receita):
    def __init__(self, titulo, ingredientes, tempo_preparo, nivel_acucar):
        super().__init__(titulo, ingredientes, tempo_preparo)
        self.nivel_acucar = nivel_acucar

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Nível de açúcar: {self.nivel_acucar}%")
        if self.nivel_acucar > 50:
            print("⚠️ Atenção: Alto teor de açúcar!")
        print("-" * 40)

# ================================
# FUNÇÕES DE BANCO DE DADOS
# ================================
def inserir_receita(titulo, ingredientes, tempo_preparo, nivel_acucar=None):
    conn = conectar_banco()
    cursor = conn.cursor()

    try:
        # Inserir na tabela de receitas
        cursor.execute('''
            INSERT INTO receitas (titulo, ingredientes, tempo_preparo)
            VALUES (%s, %s, %s)
        ''', (titulo, ', '.join(ingredientes), tempo_preparo))
        conn.commit()
        receita_id = cursor.lastrowid

        # Se for sobremesa, insere na tabela de sobremesas
        if nivel_acucar is not None:
            cursor.execute('''
                INSERT INTO sobremesas (id_receita, nivel_acucar)
                VALUES (%s, %s)
            ''', (receita_id, nivel_acucar))
            conn.commit()

        print(f"✅ Receita '{titulo}' adicionada ao banco de dados.")
    except Exception as e:
        print("Erro ao inserir no banco:", e)
        conn.rollback()
    finally:
        cursor.close()
        conn.close()

def consultar_receitas():
    conn = conectar_banco()
    cursor = conn.cursor()

    try:
        cursor.execute('''
            SELECT r.id, r.titulo, r.ingredientes, r.tempo_preparo, s.nivel_acucar
            FROM receitas r
            LEFT JOIN sobremesas s ON r.id = s.id_receita
        ''')
        receitas = cursor.fetchall()

        print("\n📋 RECEITAS CADASTRADAS NO BANCO:")
        for r in receitas:
            print(f"ID: {r[0]} | Título: {r[1]} | Ingredientes: {r[2]} | Tempo: {r[3]} min", end='')
            if r[4] is not None:
                print(f" | Açúcar: {r[4]}%")
            else:
                print()
    except Exception as e:
        print("Erro na consulta:", e)
    finally:
        cursor.close()
        conn.close()

def deletar_receita(id_receita):
    conn = conectar_banco()
    cursor = conn.cursor()

    try:
        cursor.execute("DELETE FROM receitas WHERE id = %s", (id_receita,))
        conn.commit()
        print(f"🗑️ Receita com ID {id_receita} foi excluída.")
    except Exception as e:
        print("Erro ao excluir receita:", e)
        conn.rollback()
    finally:
        cursor.close()
        conn.close()

# ================================
# ADICIONAR RECEITA
# ================================
def adicionar_receita():
    titulo = input("Digite o título da receita: ")
    ingredientes = input("Digite os ingredientes (separados por vírgula): ").split(",")

    while True:
        try:
            tempo_preparo = int(input("Digite o tempo de preparo em minutos: "))
            break
        except ValueError:
            print("⚠️ Por favor, digite um número inteiro válido para o tempo!")

    sobremesa = input("É uma sobremesa? (s/n): ").strip().lower()

    if sobremesa == 's':
        while True:
            try:
                nivel_acucar = int(input("Qual o nível de açúcar (em %)? "))
                break
            except ValueError:
                print("⚠️ Digite um número válido para o nível de açúcar!")
        
        receita = ReceitaSobremesa(titulo, ingredientes, tempo_preparo, nivel_acucar)
    else:
        receita = Receita(titulo, ingredientes, tempo_preparo)
        nivel_acucar = None

    receita.exibir_dados()
    inserir_receita(titulo, ingredientes, tempo_preparo, nivel_acucar)

# ================================
# MENU
# ================================
def menu():
    while True:
        print("\n==== MENU ====")
        print("1 - Adicionar nova receita")
        print("2 - Consultar receitas")
        print("3 - Deletar receita")
        print("4 - Sair")
        
        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            adicionar_receita()
        elif opcao == "2":
            consultar_receitas()
        elif opcao == "3":
            try:
                id_receita = int(input("Digite o ID da receita a excluir: "))
                deletar_receita(id_receita)
            except ValueError:
                print("⚠️ Por favor, digite um número inteiro válido para o ID.")
        elif opcao == "4":
            print("Volte para mais receitas!")
            break
        else:
            print("❌ Opção inválida. Tente novamente.")

# ================================
# MAIN
# ================================
def main():
    print("✅ Sistema de receitas iniciado com MySQL!")
    menu()

if __name__ == "__main__":
    main()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ✅ Sistema de receitas iniciado com MySQL!
#
# ==== MENU ====
# 1 - Adicionar nova receita
# 2 - Consultar receitas
# 3 - Deletar receita
# 4 - Sair
# Escolha uma opção: 2
#
# 📋 RECEITAS CADASTRADAS NO BANCO:
# ID: 1 | Título: qwe | Ingredientes: qwe,  qwe,  wqe | Tempo: 123 min | Açúcar: 1%
#
# ==== MENU ====
# 1 - Adicionar nova receita
# 2 - Consultar receitas
# 3 - Deletar receita
# 4 - Sair
# Escolha uma opção: 3
# Digite o ID da receita a excluir: 1
# 🗑️ Receita com ID 1 foi excluída.
#
# ==== MENU ====
# 1 - Adicionar nova receita
# 2 - Consultar receitas
# 3 - Deletar receita
# 4 - Sair
# Escolha uma opção: 1
# Digite o título da receita: gustavofadelmodro
# Digite os ingredientes (separados por vírgula): gustavo, fadel, modro
# Digite o tempo de preparo em minutos: 8
# É uma sobremesa? (s/n): s
# Qual o nível de açúcar (em %)? 1
#
# Receita: gustavofadelmodro
# ...
